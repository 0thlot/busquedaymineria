# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import pandas as pd

# %%
fl=pd.read_csv('index/100k/ramHeap/heap.dat', sep='\t', lineterminator='\n',header=None,names=['TamDoc', 'NTerm'])

# %%
fl
# Out:
#           TamDoc    NTerm
# 0           1870      906
# 1           2321     1090
# 2           3236     1319
# 3           4894     2016
# 4           5275     2145
# 5           6908     2416
# 6           7278     2522
# 7           7504     2586
# 8           8540     2935
# 9           9644     3221
# 10         10359     3396
# 11         11553     3644
# 12         12631     3874
# 13         13171     4005
# 14         16804     4782
# 15         18113     4997
# 16         19930     5602
# 17         20454     5728
# 18         20994     5900
# 19         23950     6311
# 20         24942     6390
# 21         25166     6443
# 22         25559     6490
# 23         25762     6537
# 24         26758     6693
# 25         28718     6932
# 26         37080     7920
# 27         37401     7948
# 28         39126     8191
# 29         39632     8265
# ...          ...      ...
# 97995  140488580  1254003
# 97996  140489715  1254006
# 97997  140490573  1254012
# ...

# %%
fig, ax = plt.subplots()
ax.plot(fl['TamDoc'], fl['NTerm'])

ax.set(xlabel='Tamaño de la coleccion', ylabel='Tamaño conjunto terminos',
       title='Ley de Heap con 100K documentos')
ax.grid()

fig.savefig("test.png")
plt.show()
